# %% [markdown]
# <a href="https://colab.research.google.com/github/Jonah-30/neural-network-for-fashion_mnistst-dataset/blob/main/Copy_of_neuralNetworkipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing libraries and datasets.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# seperate dataset into inputs and outputs and training and testing
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.fashion_mnist.load_data()

# normalize images by scaling the pixels from 0 to 1
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print("x_train shape:", x_train.shape, "y_train shape:", y_train.shape)

# reshape the images
x_train = x_train.reshape((60000,28,28,1))
x_test = x_test.reshape((10000,28,28,1))

# Reshape the outputs
y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# the names of each classification
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Anke Boot']
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# x_train shape: (60000, 28, 28) y_train shape: (60000,)

# %% [markdown]
# Display sample images.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.reshape(x_test[i], newshape=(28, 28)), cmap=plt.cm.binary)
    for j in range(0, 10):
      if y_test[i][j] == 1:
        number = j
        break
    plt.xlabel(class_names[j])
plt.show()

# %% [markdown]
# Setting up the neural network.

# %%
from tensorflow.keras.layers import Dense,Flatten,Conv2D,MaxPooling2D


# add layers
model = tf.keras.Sequential()
model.add(Conv2D(filters=64,kernel_size=(4,4),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(filters=64,kernel_size=(4,4),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())

model.add(Dense(256,activation='relu'))
model.add(Dense(10,activation='softmax'))

model.summary()

# setup the back-propagation
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 25, 25, 64)        1088
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 9, 9, 64)          65600
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 256)               262400
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 331,658
# Trainable params: 331,658
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model.

# %%
history = model.fit(x_test, y_test, batch_size=32, epochs=10, validation_data=(x_train, y_train))
# Out:
# Epoch 1/10
# 313/313 [==============================] - 41s 130ms/step - loss: 1.0283 - accuracy: 0.6295 - val_loss: 0.5107 - val_accuracy: 0.8138
# Epoch 2/10
# 313/313 [==============================] - 40s 127ms/step - loss: 0.5012 - accuracy: 0.8164 - val_loss: 0.4802 - val_accuracy: 0.8179
# Epoch 3/10
# 313/313 [==============================] - 40s 128ms/step - loss: 0.4117 - accuracy: 0.8482 - val_loss: 0.3952 - val_accuracy: 0.8568
# Epoch 4/10
# 313/313 [==============================] - 40s 129ms/step - loss: 0.3481 - accuracy: 0.8744 - val_loss: 0.3700 - val_accuracy: 0.8647
# Epoch 5/10
# 313/313 [==============================] - 40s 128ms/step - loss: 0.3021 - accuracy: 0.8881 - val_loss: 0.3563 - val_accuracy: 0.8690
# Epoch 6/10
# 313/313 [==============================] - 40s 127ms/step - loss: 0.2711 - accuracy: 0.9004 - val_loss: 0.3478 - val_accuracy: 0.8741
# Epoch 7/10
# 313/313 [==============================] - 40s 129ms/step - loss: 0.2309 - accuracy: 0.9200 - val_loss: 0.3511 - val_accuracy: 0.8746
# Epoch 8/10
# 313/313 [==============================] - 40s 128ms/step - loss: 0.2213 - accuracy: 0.9166 - val_loss: 0.3543 - val_accuracy: 0.8763
# Epoch 9/10
# 313/313 [==============================] - 40s 127ms/step - loss: 0.1895 - accuracy: 0.9310 - val_loss: 0.4047 - val_accuracy: 0.8662
# Epoch 10/10
# 313/313 [==============================] - 40s 128ms/step - loss: 0.1743 - accuracy: 0.9369 - val_loss: 0.3669 - val_accuracy: 0.8802

# %% [markdown]
# Evaluate the loss and accuracy of the testing dataset

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)

print(test_loss, test_acc)
# Out:
# 313/313 - 4s - loss: 0.1281 - accuracy: 0.9547
# 0.12812405824661255 0.9546999931335449

# %% [markdown]
# Save the model.

# %%
model.save('image_classifier_fashion_mnist_net.model')
new_model = tf.keras.models.load_model('image_classifier_fashion_mnist_net.model')
# Out:
# INFO:tensorflow:Assets written to: image_classifier_fashion_mnist_net.model/assets

# %% [markdown]
# Plot the results on test set.

# %%
predictions=new_model.predict([x_test])
plt.figure(figsize=(20,50))
for i in range(100):
    plt.subplot(20,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(np.reshape(x_test[i], newshape=(28, 28)), cmap=plt.cm.binary)
    for j in range(0, 10):
      if y_test[i][j] == 1:
        number = j
        break
    plt.xlabel(str(class_names[np.argmax(predictions[i])] + ' : ' + class_names[j]))
plt.show()
